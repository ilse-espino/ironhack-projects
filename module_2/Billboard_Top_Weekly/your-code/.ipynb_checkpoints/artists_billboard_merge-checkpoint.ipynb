# %%
import pandas as pd
import numpy as np

# %%
billboard_100 = pd.read_csv("C:/Users/Admin/Documents/ironhack/BillboardFromLast20/billboardHot100_1999-2019_clean.csv")

# %%
billboard_100
# Out:
#                                    Artists                      Name  \
# 0                              ['Lil Nas']             Old Town Road
# 1      ['Shawn Mendes', ' Camila Cabello']                  Senorita
# 2                        ['Billie Eilish']                   Bad Guy
# 3                               ['Khalid']                      Talk
# 4         ['Ed Sheeran', ' Justin Bieber']              I Don't Care
# ...                                    ...                       ...
# 97220                        ['Vitamin C']                     Smile
# 97221                  ['Collective Soul']                     Heavy
# 97222            ['Mary Chapin Carpenter']               Almost Home
# 97223                                ['Q']             Vivrant Thing
# 97224                    ['The Offspring']  Why Don't You Get A Job?
#
#        Weekly.rank  Peak.position  Weeks.on.chart        Week  \
# 0                1            1.0             7.0  2019-07-06
# ...

# %%
artists = pd.read_csv("C:/Users/Admin/Documents/ironhack/BillboardFromLast20/artistDf.csv")

# %%
artists
# Out:
#          X           Artist  Followers  \
# 0        0       Ed Sheeran   52698756
# 1        1    Justin Bieber   30711450
# 2        2   Jonas Brothers    3069527
# 3        3            Drake   41420478
# 4        4      Chris Brown    9676862
# ...    ...              ...        ...
# 1030  1030    Dwight Yoakam     284597
# 1031  1031    Jordan Knight      47229
# 1032  1032      Lila McCann      42444
# 1033  1033         Everlast     200550
# 1034  1034  Collective Soul     525701
#
#                                                  Genres  NumAlbums  \
# 0                                            pop,uk pop          8
# 1              canadian pop,dance pop,pop,post-teen pop         10
# 2                  boy band,dance pop,pop,post-teen pop         10
# 3     canadian hip hop,canadian pop,hip hop,pop rap,...         11
# 4                         dance pop,pop,pop rap,r&b,rap          6
# ...                                                 ...        ...
# ...

# %%
gender_artists = billboard_100.merge(right=artists, how="left", left_on="main_artist", right_on="Artist")

# %%
gender_artists.head()
# Out:
#                                Artists           Name  Weekly.rank  \
# 0                          ['Lil Nas']  Old Town Road            1
# 1  ['Shawn Mendes', ' Camila Cabello']       Senorita            2
# 2                    ['Billie Eilish']        Bad Guy            3
# 3                           ['Khalid']           Talk            4
# 4     ['Ed Sheeran', ' Justin Bieber']   I Don't Care            5
#
#    Peak.position  Weeks.on.chart        Week              Date  \
# 0            1.0             7.0  2019-07-06     April 5, 2019
# 1            NaN             NaN  2019-07-06     June 21, 2019
# 2            2.0            13.0  2019-07-06    March 29, 2019
# 3            3.0            20.0  2019-07-06  February 7, 2019
# 4            2.0             7.0  2019-07-06      May 10, 2019
#
#                                                Genre  \
# 0  ['Country', 'Atlanta', 'Alternative Country', ...
# 1                                            ['Pop']
# ...

# %%
gender_artists.to_csv("C:/Users/Admin/Documents/ironhack/BillboardFromLast20/artists_billboard_merge.csv", index=False)
