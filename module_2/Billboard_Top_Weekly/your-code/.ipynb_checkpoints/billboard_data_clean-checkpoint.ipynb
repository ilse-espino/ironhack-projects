# %%
import pandas as pd
import numpy as np

# %%
billboard_100 = pd.read_csv("C:/Users/Admin/Documents/ironhack/BillboardFromLast20/billboardHot100_1999-2019.csv")

# %%
billboard_100.head()
# Out:
#    Unnamed: 0                       Artists           Name  Weekly.rank  \
# 0           1                      Lil Nas,  Old Town Road            1
# 1           2  Shawn Mendes, Camila Cabello       Senorita            2
# 2           3                 Billie Eilish        Bad Guy            3
# 3           4                        Khalid           Talk            4
# 4           5     Ed Sheeran, Justin Bieber   I Don't Care            5
#
#    Peak.position  Weeks.on.chart        Week              Date  \
# 0            1.0             7.0  2019-07-06     April 5, 2019
# 1            NaN             NaN  2019-07-06     June 21, 2019
# 2            2.0            13.0  2019-07-06    March 29, 2019
# 3            3.0            20.0  2019-07-06  February 7, 2019
# 4            2.0             7.0  2019-07-06      May 10, 2019
#
#                                                Genre  \
# 0  Country,Atlanta,Alternative Country,Hip-Hop,Tr...
# ...

# %%
billboard_100["Genre"] = billboard_100["Genre"].str.split(",")

# %%
billboard_100.head()
# Out:
#    Unnamed: 0                       Artists           Name  Weekly.rank  \
# 0           1                      Lil Nas,  Old Town Road            1
# 1           2  Shawn Mendes, Camila Cabello       Senorita            2
# 2           3                 Billie Eilish        Bad Guy            3
# 3           4                        Khalid           Talk            4
# 4           5     Ed Sheeran, Justin Bieber   I Don't Care            5
#
#    Peak.position  Weeks.on.chart        Week              Date  \
# 0            1.0             7.0  2019-07-06     April 5, 2019
# 1            NaN             NaN  2019-07-06     June 21, 2019
# 2            2.0            13.0  2019-07-06    March 29, 2019
# 3            3.0            20.0  2019-07-06  February 7, 2019
# 4            2.0             7.0  2019-07-06      May 10, 2019
#
#                                                Genre  \
# 0  [Country, Atlanta, Alternative Country, Hip-Ho...
# ...

# %%
billboard_100["Genre"][0][0]
# Out:
# 'Country'

# %%
genres = list(billboard_100["Genre"])

# %%
top_genres = [i[0] for i in genres]

# %%
billboard_100["top_genre"] = top_genres

# %%
billboard_100.head(50)
# Out:
#     Unnamed: 0                            Artists  \
# 0            1                           Lil Nas,
# 1            2       Shawn Mendes, Camila Cabello
# 2            3                      Billie Eilish
# 3            4                             Khalid
# 4            5          Ed Sheeran, Justin Bieber
# 5            6                     Jonas Brothers
# 6            7                             DaBaby
# 7            8                              Drake
# 8            9                        Chris Brown
# 9           10                        Post Malone
# 10          11                              Lizzo
# 11          12              Post Malone, Swae Lee
# 12          13                       Taylor Swift
# 13          14                       Shawn Mendes
# 14          15                 Sam Smith, Normani
# 15          16                          Lil Nas X
# 16          17                             Halsey
# 17          18                      Blake Shelton
# ...

# %%
billboard_100["artists_original"] = billboard_100["Artists"]

# %%
#billboard_100.loc[np.where(billboard_100["Artists"] == "Tyler, The Creator")]["Artists"]



billboard_100["Artists"] = (np.where(billboard_100["Artists"] == "Tyler, The Creator"
                                     , "Tyler The Creator"
                                     , billboard_100["Artists"]))

# %%
billboard_100.loc[np.where(billboard_100["Artists"] == "Tyler, The Creator")]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Artists, Name, Weekly.rank, Peak.position, Weeks.on.chart, Week, Date, Genre, Writing.Credits, Lyrics, Features, top_genre, artists_original]
# Index: []

# %%
billboard_100.head()
# Out:
#    Unnamed: 0                       Artists           Name  Weekly.rank  \
# 0           1                      Lil Nas,  Old Town Road            1
# 1           2  Shawn Mendes, Camila Cabello       Senorita            2
# 2           3                 Billie Eilish        Bad Guy            3
# 3           4                        Khalid           Talk            4
# 4           5     Ed Sheeran, Justin Bieber   I Don't Care            5
#
#    Peak.position  Weeks.on.chart        Week              Date  \
# 0            1.0             7.0  2019-07-06     April 5, 2019
# 1            NaN             NaN  2019-07-06     June 21, 2019
# 2            2.0            13.0  2019-07-06    March 29, 2019
# 3            3.0            20.0  2019-07-06  February 7, 2019
# 4            2.0             7.0  2019-07-06      May 10, 2019
#
#                                                Genre  \
# 0  [Country, Atlanta, Alternative Country, Hip-Ho...
# ...

# %%
billboard_100["Artists"] = billboard_100["Artists"].str.split(",")

# %%
artists = list(billboard_100["Artists"])

# %%
billboard_100["main_artist"] = [i[0] for i in artists]

# %%
billboard_100.head()
# Out:
#    Unnamed: 0                          Artists           Name  Weekly.rank  \
# 0           1                      [Lil Nas, ]  Old Town Road            1
# 1           2  [Shawn Mendes,  Camila Cabello]       Senorita            2
# 2           3                  [Billie Eilish]        Bad Guy            3
# 3           4                         [Khalid]           Talk            4
# 4           5     [Ed Sheeran,  Justin Bieber]   I Don't Care            5
#
#    Peak.position  Weeks.on.chart        Week              Date  \
# 0            1.0             7.0  2019-07-06     April 5, 2019
# 1            NaN             NaN  2019-07-06     June 21, 2019
# 2            2.0            13.0  2019-07-06    March 29, 2019
# 3            3.0            20.0  2019-07-06  February 7, 2019
# 4            2.0             7.0  2019-07-06      May 10, 2019
#
#                                                Genre  \
# 0  [Country, Atlanta, Alternative Country, Hip-Ho...
# ...

# %%
len(billboard_100["Artists"][3])
# Out:
# 1

# %%
#billboard_100 = billboard_100.drop(columns="Unnamed: 0")

# %%
billboard_100.head()
# Out:
#                            Artists           Name  Weekly.rank  Peak.position  \
# 0                        [Lil Nas]  Old Town Road            1            1.0
# 1  [Shawn Mendes,  Camila Cabello]       Senorita            2            NaN
# 2                  [Billie Eilish]        Bad Guy            3            2.0
# 3                         [Khalid]           Talk            4            3.0
# 4     [Ed Sheeran,  Justin Bieber]   I Don't Care            5            2.0
#
#    Weeks.on.chart        Week              Date  \
# 0             7.0  2019-07-06     April 5, 2019
# 1             NaN  2019-07-06     June 21, 2019
# 2            13.0  2019-07-06    March 29, 2019
# 3            20.0  2019-07-06  February 7, 2019
# 4             7.0  2019-07-06      May 10, 2019
#
#                                                Genre  \
# 0  [Country, Atlanta, Alternative Country, Hip-Ho...
# 1                                              [Pop]
# ...

# %%
#billboard_100["Artists"][0] = [billboard_100["Artists"][0][0]]
# Out:
# C:\Users\Admin\.conda\envs\backpack_banana\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
billboard_100["no_artists"] = [len(billboard_100["Artists"][i]) for i in range(len(billboard_100["Artists"]))]

# %%
billboard_100
# Out:
#                                Artists                      Name  Weekly.rank  \
# 0                            [Lil Nas]             Old Town Road            1
# 1      [Shawn Mendes,  Camila Cabello]                  Senorita            2
# 2                      [Billie Eilish]                   Bad Guy            3
# 3                             [Khalid]                      Talk            4
# 4         [Ed Sheeran,  Justin Bieber]              I Don't Care            5
# ...                                ...                       ...          ...
# 97220                      [Vitamin C]                     Smile           95
# 97221                [Collective Soul]                     Heavy           96
# 97222          [Mary Chapin Carpenter]               Almost Home           97
# 97223                              [Q]             Vivrant Thing           98
# 97224                  [The Offspring]  Why Don't You Get A Job?          100
#
# ...

# %%
billboard_100 = billboard_100.drop(columns="Lyrics")

# %%
#billboard_100.to_csv("C:/Users/Admin/Documents/ironhack/BillboardFromLast20/billboardHot100_1999-2019_clean.csv", index=False)

# %%
np.where(billboard_100["top_genre"] == "Alternative Rock")
# Out:
# (array([   49,   142,   240, ..., 97023, 97075, 97158], dtype=int64),)
