# %%
import module_escape_room
exit = 0
while exit == 0:
    module_escape_room.game_state = module_escape_room.init_game_state()
    module_escape_room.object_relations = module_escape_room.init_object_relations()
    module_escape_room.start_game()
    exit = module_escape_room.play_again()
# Out:
# You wake up on a couch and find yourself in a strange house with no windows which you have never been to before. You don't remember why you are here and what had happened before. You feel some unknown danger is approaching and you must get out of the house, NOW!
#
#                            .-----.
#                          .'       `.
#                         :      ^v^  :
#                         :           :
#                         '           '
#          |~        www   `.       .'
#         /.\       /#^^\_   `-/\--'
#        /#  \     /#%    \   /#       /#%   \   /#%______\ /#%__     /#%     \   |= I I ||  |- |
#      ~~|~~~|~~   |_=_-__|'  |[]|
#        |[] |_______\__|/_ _ |= |`.
# ^V^    |-  /= __   __    /-\|= | :;
#        |= /- /\/  /\/   /=- \.-' :;
#        | /_.=========._/_.-._\  .:'
#        |= |-.'.- .'.- |  /|\ |.:'
#        \  |=|:|= |:| =| |~|~||'|
#         |~|-|:| -|:|  |-|~|~||=|      ^V^
#         |=|=|:|- |:|- | |~|~|| |
# ...
